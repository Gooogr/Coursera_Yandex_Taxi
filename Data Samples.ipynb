# %%
import pandas as pd

# %%
raw_data2009 = pd.read_csv('/TAXI project/TAXI DATA/2009/yellow_tripdata_2009-10.csv', nrows=5)
raw_data2009
# Out:
#   vendor_name Trip_Pickup_DateTime Trip_Dropoff_DateTime  Passenger_Count  \
# 0         VTS  2009-10-26 13:06:00   2009-10-26 13:17:00                5
# 1         VTS  2009-10-27 22:12:00   2009-10-27 22:39:00                1
# 2         VTS  2009-10-26 11:30:00   2009-10-26 11:41:00                2
# 3         VTS  2009-10-26 14:41:00   2009-10-26 14:51:00                2
# 4         VTS  2009-10-26 12:34:00   2009-10-26 12:51:00                2
#
#    Trip_Distance  Start_Lon  Start_Lat  Rate_Code  store_and_forward  \
# 0           2.02 -73.967242  40.803225        NaN                NaN
# 1          16.70 -73.783803  40.648708        NaN                NaN
# 2           1.79 -73.969985  40.752457        NaN                NaN
# 3           1.34 -73.979863  40.784093        NaN                NaN
# 4           9.21 -73.976872  40.749082        NaN                NaN
#
#      End_Lon    End_Lat Payment_Type  Fare_Amt  surcharge  mta_tax  Tip_Amt  \
# ...

# %%
raw_data2010 = pd.read_csv('/TAXI project/TAXI DATA/2010/yellow_tripdata_2010-10.csv', nrows=5)
raw_data2010
# Out:
#   vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0       CMT  2010-10-01 04:04:02  2010-10-01 04:08:31                1
# 1       CMT  2010-10-01 02:46:21  2010-10-01 02:54:31                1
# 2       CMT  2010-10-01 04:55:37  2010-10-01 04:55:43                1
# 3       CMT  2010-10-01 03:09:08  2010-10-01 03:11:47                1
# 4       CMT  2010-10-01 09:05:52  2010-10-01 09:36:22                1
#
#    trip_distance  pickup_longitude  pickup_latitude  rate_code  \
# 0            0.6        -73.981668        40.763661          1
# 1            2.5        -74.004524        40.722785          1
# 2            0.0        -73.994984        40.761136          1
# 3            0.4        -73.834215        40.766077          1
# 4           10.0        -73.862781        40.676826          1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0                  N         -73.991518         40.760422          CSH
# ...

# %%
raw_data2011 = pd.read_csv('/TAXI project/TAXI DATA/2011/yellow_tripdata_2011-10.csv', nrows=5)
raw_data2011
# Out:
#   vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0       CMT  2011-10-12 22:46:46  2011-10-12 22:55:27                1
# 1       CMT  2011-10-13 14:47:29  2011-10-13 14:55:11                1
# 2       CMT  2011-10-12 22:41:43  2011-10-12 23:07:32                1
# 3       VTS  2011-10-03 07:30:00  2011-10-03 07:31:00                1
# 4       VTS  2011-10-03 07:22:00  2011-10-03 07:34:00                1
#
#    trip_distance  pickup_longitude  pickup_latitude  rate_code  \
# 0           1.10        -74.009446        40.723418          1
# 1           1.00        -73.967310        40.769387          1
# 2           5.00        -73.985800        40.727700          1
# 3           0.35        -73.958442        40.760252          1
# 4           4.61        -73.975920        40.748685          1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0                  N         -74.010464         40.709606          CSH
# ...

# %%
raw_data2012 = pd.read_csv('/TAXI project/TAXI DATA/2012/yellow_tripdata_2012-10.csv', nrows=5)
raw_data2011
# Out:
#   vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0       CMT  2011-10-12 22:46:46  2011-10-12 22:55:27                1
# 1       CMT  2011-10-13 14:47:29  2011-10-13 14:55:11                1
# 2       CMT  2011-10-12 22:41:43  2011-10-12 23:07:32                1
# 3       VTS  2011-10-03 07:30:00  2011-10-03 07:31:00                1
# 4       VTS  2011-10-03 07:22:00  2011-10-03 07:34:00                1
#
#    trip_distance  pickup_longitude  pickup_latitude  rate_code  \
# 0           1.10        -74.009446        40.723418          1
# 1           1.00        -73.967310        40.769387          1
# 2           5.00        -73.985800        40.727700          1
# 3           0.35        -73.958442        40.760252          1
# 4           4.61        -73.975920        40.748685          1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0                  N         -74.010464         40.709606          CSH
# ...

# %%
raw_data2013 = pd.read_csv('/TAXI project/TAXI DATA/2013/yellow_tripdata_2013-10.csv', nrows=5)
raw_data2013
# Out:
#   vendor_id      pickup_datetime     dropoff_datetime  passenger_count  \
# 0       CMT  2013-10-09 14:46:30  2013-10-09 14:56:02                1
# 1       CMT  2013-10-09 17:32:08  2013-10-09 17:45:40                1
# 2       CMT  2013-10-07 11:47:37  2013-10-07 11:55:42                1
# 3       CMT  2013-10-12 04:51:00  2013-10-12 05:00:36                1
# 4       CMT  2013-10-13 22:56:01  2013-10-13 23:09:43                1
#
#    trip_distance  pickup_longitude  pickup_latitude  rate_code  \
# 0            1.1        -73.986868        40.756240          1
# 1            2.9        -74.001103        40.721382          1
# 2            1.2        -73.973728        40.782853          1
# 3            2.4        -73.910289        40.776281          1
# 4            2.7        -73.980677        40.784765          1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0                  N         -73.980561         40.764797          CRD
# ...

# %%
raw_data2014 = pd.read_csv('/TAXI project/TAXI DATA/2014/yellow_tripdata_2014-10.csv', nrows=5)
raw_data2014
# Out:
#   vendor_id      pickup_datetime     dropoff_datetime   passenger_count  \
# 0       CMT  2014-10-01 08:55:07  2014-10-01 09:11:03                 1
# 1       CMT  2014-10-01 10:51:17  2014-10-01 11:26:11                 1
# 2       CMT  2014-10-01 02:03:03  2014-10-01 02:06:55                 1
# 3       CMT  2014-10-01 00:06:35  2014-10-01 00:17:05                 2
# 4       CMT  2014-10-01 01:34:13  2014-10-01 01:47:02                 1
#
#     trip_distance   pickup_longitude   pickup_latitude   rate_code  \
# 0             2.2         -74.005867         40.737570           1
# 1            15.7         -73.873193         40.774056           1
# 2             1.0           0.000000          0.000000           1
# 3             2.5         -73.987151         40.732922           1
# 4             4.2         -73.983267         40.726577           1
#
#    store_and_fwd_flag   dropoff_longitude   dropoff_latitude  payment_type  \
# ...

# %%
raw_data2015 = pd.read_csv('/TAXI project/TAXI DATA/2015/yellow_tripdata_2015-10.csv', nrows=5)
raw_data2015
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2015-10-01 00:00:00   2015-10-01 00:05:48                1
# 1         2  2015-10-01 00:00:00   2015-10-01 00:00:00                1
# 2         2  2015-10-01 00:00:00   2015-10-01 00:00:00                2
# 3         2  2015-10-01 00:00:00   2015-10-01 00:00:00                0
# 4         1  2015-10-01 00:00:01   2015-10-01 00:16:19                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.10        -73.935516        40.761238           1
# 1           7.68        -73.989937        40.743439           1
# 2           2.53        -73.987328        40.720020           1
# 3           1.20        -73.953758        40.743385           5
# 4           3.80        -73.984016        40.755222           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
raw_data2016 = pd.read_csv('/TAXI project/TAXI DATA/2016/yellow_tripdata_2016-10.csv', nrows=5)
raw_data2016
# Out:
#                                   VendorID  tpep_pickup_datetime  \
# 1 2016-10-01 00:00:00  2016-10-01 00:10:45                     3
# 2 2016-10-01 00:00:00  2016-10-01 00:15:51                     5
#   2016-10-01 00:00:00  2016-10-01 00:03:22                     5
#   2016-10-01 00:00:00  2016-10-01 00:15:35                     4
#   2016-10-01 00:00:00  2016-10-01 00:14:33                     2
#
#                        tpep_dropoff_datetime  passenger_count trip_distance  \
# 1 2016-10-01 00:00:00                   3.40                1             N
# 2 2016-10-01 00:00:00                   4.17                1             N
#   2016-10-01 00:00:00                   0.66                1             N
#   2016-10-01 00:00:00                   2.49                1             N
#   2016-10-01 00:00:00                   3.81                1             N
#
#                        RatecodeID  store_and_fwd_flag  PULocationID  \
# ...

# %% [markdown]
# Названия интересющих столбцов координат:
# * 2009 - 'Start_Lon', 'Start_Lat'
# * 2010 - 'pickup_longitude', 'pickup_latitude'
# * 2011 - 'pickup_longitude', 'pickup_latitude'
# * 2012 - 'pickup_longitude', 'pickup_latitude'
# * 2013 - 'pickup_longitude', 'pickup_latitude'
# * 2014 - ' pickup_longitude', ' pickup_latitude'
# * 2015 - 'pickup_longitude', 'pickup_latitude'
# * 2016 - первые 6 месяцев  'pickup_longitude', 'pickup_latitude'
